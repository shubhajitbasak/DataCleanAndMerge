# %% [markdown]
# ### Data Cleaning & Merging
# ##### Author : Shubhajit Basak
# ##### Merge data from multi source Open Data

# %%
# Import Packages
import pandas as pd
import numpy as np 
from geopy.geocoders import Nominatim
from enum import Enum
import xml.etree.ElementTree as ET
from datetime import datetime
import folium

# %% [markdown]
# #### Generic Methods that will used later

# %%
# Method To trim extra spaces accross the data of a dataframe
def trimAllColumns(df):
    """
    Trim whitespace from ends of each value across all series in dataframe
    """
    trimStrings = lambda x: x.strip() if type(x) is str else x
    return df.applymap(trimStrings)


#Method to get the Location from Latitude and Longitude Data
geolocator = Nominatim(user_agent="my_app", country_bias='Ireland', timeout=None)

def getLocatonFromLatLong(lat,long):
    location = geolocator.reverse([(lat,long)])
    return location.address.split(", ")[-6]

# %% [markdown]
# #### Load the three datasets

# %%
#Read and load the DCC and DLR data from csv
dcc = pd.read_csv("dcc_pitches.csv")
dlr = pd.read_csv("dlr_pitches.csv")

# %%
# Load the data for FCC from a XML 
# Code Reference 
# https://www.kaggle.com/ysviru/simple-analysis-of-healthcare-job-postings

#Build the XML Model 
class XMLTagsUpperLevel:
    """
    This class defines the XML tag constants at the higher level of XML tree. 
    """
    TABLE = "Playing_Pitches-table"
    PITCHES = "Playing_Pitches"

class XMLTagsLowerLevel(Enum):
    """
    This class defines all the XML tag constants that are one level below the <Playing_Pitches> tag. This is defined as an
    enumerated type for ease of iterating over all tags.
    """
    FACILITY_TYPE = "FACILITY_TYPE"
    FACILITY_NAME = "FACILITY_NAME"
    LOCATION = "LOCATION"
    LAT = "LAT"
    LONG = "LONG"

#Class XML Parser
class XMLParser:

    def __init__(self, file_path="fcc_pitches.xml"):
        """
        Initializes the XMLParser class instance.
        :param file_path: Path to input xml file containing the data.
        """
        self.file_path = file_path


    def xml_to_pandas_df(self):
        """
        Using the standard xml python library, we parse the data xml file and convert the xml data to a pandas
        data frame.
        :return: A pandas data frame instance containing all the data.
        """
        tree = ET.parse(self.file_path)
        root = tree.getroot()

        pitches_data = dict()
        for tag in XMLTagsLowerLevel:
            pitches_data[tag.value] = []

        for i, page in enumerate(root.findall(XMLTagsUpperLevel.TABLE)):
            for j, record in enumerate(page.findall(XMLTagsUpperLevel.PITCHES)):
                for tag in XMLTagsLowerLevel:
                    temp = record.find(tag.value)
                    if temp is not None:
                        pitches_data[tag.value].append(temp.text)
                    else:
                        pitches_data[tag.value].append("")

        return pd.DataFrame(data=pitches_data)

# %%
# Read and load the FCC Data 
file_path = "fcc_pitches.xml"
parser = XMLParser(file_path)
fcc = parser.xml_to_pandas_df()

# %% [markdown]
# #### Check few records and the datacount to get the count of missing values of different field for all the files

# %%
## DCC Data
dcc.head()
# Out:
#              PARK           AREA              CLUBNAME  \
# 0  ALBERT COLLEGE     NORTH WEST  DRUMCONDRA F.C (Snr)
# 1  ALBERT COLLEGE     NORTH WEST         GLASNEVIN AFC
# 2       BEECHILL      SOUTH EAST        BALLSBRIDGE FC
# 3         BELCAMP  NORTH CENTRAL        NEWTOWN CELTIC
# 4         BELCAMP  NORTH CENTRAL          VIANNEY BOYS
#
#                     LEAGUE  Unnamed: 4
# 0  AMATEUR FOOTBALL LEAGUE         NaN
# 1  AMATEUR FOOTBALL LEAGUE         NaN
# 2  AMATEUR FOOTBALL LEAGUE         NaN
# 3  AMATEUR FOOTBALL LEAGUE         NaN
# 4  AMATEUR FOOTBALL LEAGUE         NaN

# %%
# dcc Count 
print(dcc.count())
# counts of null values in different columns
print(dcc.isnull().sum(axis = 0))
# Out:
# PARK          250
# AREA          250
# CLUBNAME      250
# LEAGUE        250
# Unnamed: 4      0
# dtype: int64
# PARK            0
# AREA            0
# CLUBNAME        0
# LEAGUE          0
# Unnamed: 4    250
# dtype: int64

# %% [markdown]
# <b> Observation </b> - There are total 250 records for DCC and none of the column has missing values, though the Latitude, Longitude, Location and Pitch Type are missing

# %%
dlr.head()
# Out:
#          Location Number Size   Latitude  Longitude
# 0  Kilbogget Park      1  Snr  53.257242  -6.140665
# 1             NaN      2  SSG  53.257614  -6.139882
# 2             NaN      3  SSG  53.257842  -6.139265
# 3             NaN      4  SSG  53.257098  -6.139094
# 4             NaN      5  SGG  53.256674  -6.140134

# %%
# dlr Count 
print(dlr.count())
# counts of null values in different columns
print(dlr.isnull().sum(axis = 0))
# Out:
# Location     15
# Number       60
# Size         58
# Latitude     60
# Longitude    60
# dtype: int64
# Location     46
# Number        1
# Size          3
# Latitude      1
# Longitude     1
# dtype: int64

# %% [markdown]
# <b> Observation </b> - There are total 61 records for DLR and in which for 46 records Loaction is missing, Pitch Number, Latitude and Longitude are missing for one record and Pitch Size is missing for 3 values

# %%
fcc.head()
# Out:
#           FACILITY_NAME        FACILITY_TYPE               LAT    LOCATION  \
# 0  Balbriggan Town Park  All weather pitches  53.6049596246817  Balbriggan
# 1    Balheary Reservoir  All weather pitches  53.4727096370551      Swords
# 2             Town Park  All weather pitches  53.5771135903791    Skerries
# 3     St. Mologa's Park  All weather pitches  53.6176672458903  Balbriggan
# 4        Seagrange Park     Basketball Court  53.3966674985382        None
#
#                 LONG
# 0  -6.18235291959051
# 1  -6.22301521551813
# 2  -6.11107205744599
# 3  -6.18936794084573
# 4  -6.13535180348378

# %%
# fcc Count 
print(fcc.count())
# counts of null values in different columns
print(fcc.isnull().sum(axis = 0))
# Out:
# FACILITY_NAME    96
# FACILITY_TYPE    96
# LAT              96
# LOCATION         73
# LONG             96
# dtype: int64
# FACILITY_NAME     0
# FACILITY_TYPE     0
# LAT               0
# LOCATION         23
# LONG              0
# dtype: int64

# %% [markdown]
# <b> Observation </b> - There are total 96 records for FCC and in which for 23 records Loaction is missing

# %% [markdown]
# #### Data Quality Enhancement

# %%
#Trim all the string columns of the three dataset
dcc = trimAllColumns(dcc)
dlr = trimAllColumns(dlr)
fcc = trimAllColumns(fcc)

# %%
## Clean the DCC Dataset 

#Drop the extra column at right (which came due to an extra comma) from DCC Dataset
dcc = dcc.drop(dcc.columns[4],1)

# Rename the column names of DCC 
dcc.columns = ['Park','Area','ClubName','League']

dcc.head()
# Out:
#              Park           Area              ClubName  \
# 0  ALBERT COLLEGE     NORTH WEST  DRUMCONDRA F.C (Snr)
# 1  ALBERT COLLEGE     NORTH WEST         GLASNEVIN AFC
# 2        BEECHILL     SOUTH EAST        BALLSBRIDGE FC
# 3         BELCAMP  NORTH CENTRAL        NEWTOWN CELTIC
# 4         BELCAMP  NORTH CENTRAL          VIANNEY BOYS
#
#                     League
# 0  AMATEUR FOOTBALL LEAGUE
# 1  AMATEUR FOOTBALL LEAGUE
# 2  AMATEUR FOOTBALL LEAGUE
# 3  AMATEUR FOOTBALL LEAGUE
# 4  AMATEUR FOOTBALL LEAGUE

# %%
## Clean and modify FCC Dataset 

#Reorder the columns
fcc = fcc[["FACILITY_NAME","FACILITY_TYPE","LOCATION","LAT","LONG"]]

#Rename the FCC Columns so that it will help while merging the data
fcc.columns = ['Park','TypeOfPitch','Location','Latitude','Longitude']
fcc.head()
# Out:
#                    Park          TypeOfPitch    Location          Latitude  \
# 0  Balbriggan Town Park  All weather pitches  Balbriggan  53.6049596246817
# 1    Balheary Reservoir  All weather pitches      Swords  53.4727096370551
# 2             Town Park  All weather pitches    Skerries  53.5771135903791
# 3     St. Mologa's Park  All weather pitches  Balbriggan  53.6176672458903
# 4        Seagrange Park     Basketball Court        None  53.3966674985382
#
#            Longitude
# 0  -6.18235291959051
# 1  -6.22301521551813
# 2  -6.11107205744599
# 3  -6.18936794084573
# 4  -6.13535180348378

# %% [markdown]
# #### Check for duplicate and drop if any in all the 3 datasets

# %%
#dlr
print(len(dlr))
dlr = dlr.drop_duplicates(subset=list(dlr), keep=False)
print(len(dlr))

#dcc
print(len(dcc))
dcc = dcc.drop_duplicates(subset=list(dcc), keep=False)
print(len(dcc))

#fcc
print(len(fcc))
fcc = fcc.drop_duplicates(subset=list(fcc), keep=False)
print(len(fcc))
# Out:
# 61
# 61
# 250
# 250
# 96
# 96

# %% [markdown]
# We have found there is no such duplicate data in terms of all column present in the individual dataset

# %% [markdown]
# #### Rename the column names of the dataframes to get a unified model

# %%
print(list(dcc))
print(list(dlr))
print(list(fcc))
# Out:
# ['Park', 'Area', 'ClubName', 'League']
# ['Location', 'Number', 'Size', 'Latitude', 'Longitude']
# ['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude']

# %%
#Rename the DLR Columns so that it will help while merging the data
dlr.columns = ['Park','TypeOfPitch','Size','Latitude','Longitude']
dlr.head()
# Out:
#              Park TypeOfPitch Size   Latitude  Longitude
# 0  Kilbogget Park           1  Snr  53.257242  -6.140665
# 1             NaN           2  SSG  53.257614  -6.139882
# 2             NaN           3  SSG  53.257842  -6.139265
# 3             NaN           4  SSG  53.257098  -6.139094
# 4             NaN           5  SGG  53.256674  -6.140134

# %%
print(list(dcc))
print(list(dlr))
print(list(fcc))
# Out:
# ['Park', 'Area', 'ClubName', 'League']
# ['Park', 'TypeOfPitch', 'Size', 'Latitude', 'Longitude']
# ['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude']

# %% [markdown]
# #### Modify the DLR Data

# %%
## Clean and fillthe missing values in FCC Dataset 

# As the data in the first column for DLR is missing, fill it with the previous one
dlr['Park'] = dlr['Park'].fillna(method='ffill')
dlr.head()
# Out:
#              Park TypeOfPitch Size   Latitude  Longitude
# 0  Kilbogget Park           1  Snr  53.257242  -6.140665
# 1  Kilbogget Park           2  SSG  53.257614  -6.139882
# 2  Kilbogget Park           3  SSG  53.257842  -6.139265
# 3  Kilbogget Park           4  SSG  53.257098  -6.139094
# 4  Kilbogget Park           5  SGG  53.256674  -6.140134

# %%
# Add the Column Location in DLR Dataset
dlr = dlr.assign(Location= np.nan)

# %%
list(dlr)
# Out:
# ['Park', 'TypeOfPitch', 'Size', 'Latitude', 'Longitude', 'Location']

# %%
# Reorder the columns for dlr
dlr = dlr[['Park', 'TypeOfPitch','Location', 'Size', 'Latitude', 'Longitude']]

# %%
#add Column City Council
dlr = dlr.assign(CityCouncil = 'Dún Laoghaire–Rathdown')

#Drop Pitch Size 
dlr = dlr.drop(dlr.columns[3],1)

# %%
list(dlr)
# Out:
# ['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude', 'CityCouncil']

# %%
# Update the locatiion from longitude and latitude if they present
for i,row in dlr.iterrows():
    if not np.isnan(dlr.iloc[i,4]):
        dlr.iloc[i,2] = getLocatonFromLatLong(dlr.iloc[i,3],dlr.iloc[i,4])

# %%
dlr.head()
# Out:
#              Park TypeOfPitch  Location   Latitude  Longitude  \
# 0  Kilbogget Park           1  Killiney  53.257242  -6.140665
# 1  Kilbogget Park           2  Killiney  53.257614  -6.139882
# 2  Kilbogget Park           3  Killiney  53.257842  -6.139265
# 3  Kilbogget Park           4  Killiney  53.257098  -6.139094
# 4  Kilbogget Park           5  Killiney  53.256674  -6.140134
#
#               CityCouncil
# 0  Dún Laoghaire–Rathdown
# 1  Dún Laoghaire–Rathdown
# 2  Dún Laoghaire–Rathdown
# 3  Dún Laoghaire–Rathdown
# 4  Dún Laoghaire–Rathdown

# %%
dlr.count()
# Out:
# Park           61
# TypeOfPitch    60
# Location       60
# Latitude       60
# Longitude      60
# CityCouncil    61
# dtype: int64

# %%
#as wehave found that latitude longitude and location is missing for a row lets identify the data 
dlr[dlr.isnull().any(axis=1)]
# Out:
#                  Park      TypeOfPitch   Location   Latitude  Longitude  \
# 28  Shanganagh Castle  Temporary pitch        NaN        NaN        NaN
# 60       Mount Albany              NaN  Blackrock  53.286265  -6.173321
#
#                CityCouncil
# 28  Dún Laoghaire–Rathdown
# 60  Dún Laoghaire–Rathdown

# %% [markdown]
# ##### As there are only two records with missing values we will manually update in two steps

# %%
# Update the location, latitude and longitude of the missing value
location1 = geolocator.geocode("Shanganagh Castle")
dlr.iloc[28,3] = location1.latitude
dlr.iloc[28,4] = location1.longitude
dlr.iloc[28,2] = location1.address.split(", ")[-6]
print(dlr.iloc[28,:])
# Out:
# Park                Shanganagh Castle
# TypeOfPitch           Temporary pitch
# Location                    Dublin 18
# Latitude                      53.2233
# Longitude                     -6.1237
# CityCouncil    Dún Laoghaire–Rathdown
# Name: 28, dtype: object

# %%
# Update the pitch type with the most common pitchtype in the dataset
# as there is only one value is missing we can make this assumption
dlr.iloc[60,1] =  dlr["TypeOfPitch"].value_counts().argmax()

# %%
#verify if there is any further null value 
dlr[dlr.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Park, TypeOfPitch, Location, Latitude, Longitude, CityCouncil]
# Index: []

# %%
dlr.head()
# Out:
#              Park TypeOfPitch  Location   Latitude  Longitude  \
# 0  Kilbogget Park           1  Killiney  53.257242  -6.140665
# 1  Kilbogget Park           2  Killiney  53.257614  -6.139882
# 2  Kilbogget Park           3  Killiney  53.257842  -6.139265
# 3  Kilbogget Park           4  Killiney  53.257098  -6.139094
# 4  Kilbogget Park           5  Killiney  53.256674  -6.140134
#
#               CityCouncil
# 0  Dún Laoghaire–Rathdown
# 1  Dún Laoghaire–Rathdown
# 2  Dún Laoghaire–Rathdown
# 3  Dún Laoghaire–Rathdown
# 4  Dún Laoghaire–Rathdown

# %% [markdown]
# #### Modify the FCC Dataset

# %%
## Check for Null Values 
fcc.count()
# Out:
# Park           96
# TypeOfPitch    96
# Location       73
# Latitude       96
# Longitude      96
# dtype: int64

# %%
list(fcc)
# Out:
# ['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude']

# %% [markdown]
# Only Location data is missing for this dataset

# %%
#Fill the locations where not present
for i,row in fcc.iterrows():
    if fcc.iloc[i,2] is None:
        fcc.iloc[i,2] = getLocatonFromLatLong(fcc.iloc[i,3],fcc.iloc[i,4])

# %%
# Add new column as City Council
fcc = fcc.assign(CityCouncil = 'Fingal')

# %%
#verify if there is any further null value 
fcc[fcc.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Park, TypeOfPitch, Location, Latitude, Longitude, CityCouncil]
# Index: []

# %%
fcc.head()
# Out:
#                    Park          TypeOfPitch    Location          Latitude  \
# 0  Balbriggan Town Park  All weather pitches  Balbriggan  53.6049596246817
# 1    Balheary Reservoir  All weather pitches      Swords  53.4727096370551
# 2             Town Park  All weather pitches    Skerries  53.5771135903791
# 3     St. Mologa's Park  All weather pitches  Balbriggan  53.6176672458903
# 4        Seagrange Park     Basketball Court   Dublin 13  53.3966674985382
#
#            Longitude CityCouncil
# 0  -6.18235291959051      Fingal
# 1  -6.22301521551813      Fingal
# 2  -6.11107205744599      Fingal
# 3  -6.18936794084573      Fingal
# 4  -6.13535180348378      Fingal

# %% [markdown]
# #### Modifying DCC Dataset

# %%
# Add Lititude, Longitude, Location, Type Of Pitch and City Council in DCC Dataset
dcc = dcc.assign(Latitude = np.nan, Longitude = np.nan, Location = None,CityCouncil = "Dublin City Council", 
                 TypeOfPitch = "Not Available")
dcc.head()
# Out:
#              Park           Area              ClubName  \
# 0  ALBERT COLLEGE     NORTH WEST  DRUMCONDRA F.C (Snr)
# 1  ALBERT COLLEGE     NORTH WEST         GLASNEVIN AFC
# 2        BEECHILL     SOUTH EAST        BALLSBRIDGE FC
# 3         BELCAMP  NORTH CENTRAL        NEWTOWN CELTIC
# 4         BELCAMP  NORTH CENTRAL          VIANNEY BOYS
#
#                     League          CityCouncil  Latitude Location  Longitude  \
# 0  AMATEUR FOOTBALL LEAGUE  Dublin City Council       NaN     None        NaN
# 1  AMATEUR FOOTBALL LEAGUE  Dublin City Council       NaN     None        NaN
# 2  AMATEUR FOOTBALL LEAGUE  Dublin City Council       NaN     None        NaN
# 3  AMATEUR FOOTBALL LEAGUE  Dublin City Council       NaN     None        NaN
# 4  AMATEUR FOOTBALL LEAGUE  Dublin City Council       NaN     None        NaN
#
#      TypeOfPitch
# 0  Not Available
# 1  Not Available
# 2  Not Available
# 3  Not Available
# 4  Not Available

# %%
#Change the order of the columns so thet it matches with data model
dcc = dcc[['Park','TypeOfPitch', 'Location', 'Latitude', 'Longitude','CityCouncil', 'Area', 'ClubName', 'League' ]]
list(dcc)
# Out:
# ['Park',
#  'TypeOfPitch',
#  'Location',
#  'Latitude',
#  'Longitude',
#  'CityCouncil',
#  'Area',
#  'ClubName',
#  'League']

# %% [markdown]
# ##### Add the Location Latitude and Longitude Data to DCC

# %%
# Search the Location by either Club Name or the Park Name and update the latitude longitude and loaction information

startTime = datetime.now()
for i, row in dcc.iterrows():
    locationOption1 = geolocator.geocode(dcc.iloc[i,7]) # Search by Club Name
    locationOption2 = geolocator.geocode(dcc.iloc[i,0]+" PARK DUBLIN") # Search by Park Name
    locationOption3 = geolocator.geocode(max(dcc.iloc[i,7].split(),key = len)+" DUBLIN") # Search by the highest length word of Club Name
    if((locationOption1 is not None) and "County Dublin" in locationOption1.address ):
        dcc.iloc[i,3] = locationOption1.latitude
        dcc.iloc[i,4] = locationOption1.longitude
        dcc.iloc[i,2] = locationOption1.address.split(", ")[-6]
    elif((locationOption2 is not None) and "County Dublin" in locationOption2.address):
        dcc.iloc[i,3] = locationOption2.latitude
        dcc.iloc[i,4] = locationOption2.longitude
        dcc.iloc[i,2] = locationOption2.address.split(", ")[-6]
    elif((locationOption3 is not None) and "County Dublin" in locationOption3.address):
        dcc.iloc[i,3] = locationOption3.latitude
        dcc.iloc[i,4] = locationOption3.longitude
        dcc.iloc[i,2] = locationOption3.address.split(", ")[-6]
    else:
        print("Data Not Found for:")
        print(dcc.iloc[i,0]+" DUBLIN")
        print(dcc.iloc[i,7])
endTime = datetime.now()
print("Total Time takes to fetch all data :")
print(endTime - startTime)
# Out:
# Data Not Found for:
# JOHN PAUL DUBLIN
# BEGGSBORO AFC SCHOOLBOYS
# Data Not Found for:
# FR. COLLINS DUBLIN
# SCHALKE ROVERS
# Total Time takes to fetch all data :
# 0:04:05.940783

# %%
#Check DCC Data for any missing values
dcc[dcc.isnull().any(axis=1)]
# Out:
#             Park    TypeOfPitch Location  Latitude  Longitude  \
# 82     JOHN PAUL  Not Available     None       NaN        NaN
# 227  FR. COLLINS  Not Available     None       NaN        NaN
#
#              CityCouncil           Area                  ClubName  \
# 82   Dublin City Council        CENTRAL  BEGGSBORO AFC SCHOOLBOYS
# 227  Dublin City Council  NORTH CENTRAL            SCHALKE ROVERS
#
#                                 League
# 82   DUBLIN DISTRICT SCHOOLBOYS LEAGUE
# 227    UNITED CHURCHES FOOTBALL LEAGUE

# %% [markdown]
# ##### As for two records the data is not available we will manually search for similar records in the dataset and update the two records

# %%
# Search for data with Club Name BEGGSBORO
dcc[dcc["ClubName"].str.contains("BEGGSBORO")]
# Out:
#          Park    TypeOfPitch  Location  Latitude  Longitude  \
# 82  JOHN PAUL  Not Available      None       NaN        NaN
# 83  JOHN PAUL  Not Available  Dublin 7  53.36496  -6.287479
#
#             CityCouncil     Area                  ClubName  \
# 82  Dublin City Council  CENTRAL  BEGGSBORO AFC SCHOOLBOYS
# 83  Dublin City Council  CENTRAL           BEGGSBORO A.F.C
#
#                                League
# 82  DUBLIN DISTRICT SCHOOLBOYS LEAGUE
# 83  DUBLIN DISTRICT SCHOOLBOYS LEAGUE

# %%
# Copy from the available Column
dcc.iloc[82,2] = dcc.iloc[83,2]
dcc.iloc[82,3] = dcc.iloc[83,3]
dcc.iloc[82,4] = dcc.iloc[83,4]
dcc[dcc["ClubName"].str.contains("BEGGSBORO")]
# Out:
#          Park    TypeOfPitch  Location  Latitude  Longitude  \
# 82  JOHN PAUL  Not Available  Dublin 7  53.36496  -6.287479
# 83  JOHN PAUL  Not Available  Dublin 7  53.36496  -6.287479
#
#             CityCouncil     Area                  ClubName  \
# 82  Dublin City Council  CENTRAL  BEGGSBORO AFC SCHOOLBOYS
# 83  Dublin City Council  CENTRAL           BEGGSBORO A.F.C
#
#                                League
# 82  DUBLIN DISTRICT SCHOOLBOYS LEAGUE
# 83  DUBLIN DISTRICT SCHOOLBOYS LEAGUE

# %%
#Search for data with clubname as  SCHALKE
dcc[dcc["ClubName"].str.contains("SCHALKE")]
# Out:
#             Park    TypeOfPitch                Location   Latitude  Longitude  \
# 227  FR. COLLINS  Not Available                    None        NaN        NaN
# 232     ST ANNES  Not Available  Shankill-Shanganagh ED  53.228847   -6.11739
#
#              CityCouncil           Area        ClubName  \
# 227  Dublin City Council  NORTH CENTRAL  SCHALKE ROVERS
# 232  Dublin City Council  NORTH CENTRAL  SCHALKE ROVERS
#
#                               League
# 227  UNITED CHURCHES FOOTBALL LEAGUE
# 232  UNITED CHURCHES FOOTBALL LEAGUE

# %%
# Copy from the available Column
dcc.iloc[227,2] = dcc.iloc[232,2]
dcc.iloc[227,3] = dcc.iloc[232,3]
dcc.iloc[227,4] = dcc.iloc[232,4]
dcc[dcc["ClubName"].str.contains("SCHALKE")]
# Out:
#             Park    TypeOfPitch                Location   Latitude  Longitude  \
# 227  FR. COLLINS  Not Available  Shankill-Shanganagh ED  53.228847   -6.11739
# 232     ST ANNES  Not Available  Shankill-Shanganagh ED  53.228847   -6.11739
#
#              CityCouncil           Area        ClubName  \
# 227  Dublin City Council  NORTH CENTRAL  SCHALKE ROVERS
# 232  Dublin City Council  NORTH CENTRAL  SCHALKE ROVERS
#
#                               League
# 227  UNITED CHURCHES FOOTBALL LEAGUE
# 232  UNITED CHURCHES FOOTBALL LEAGUE

# %%
# Check for any null values
dcc[dcc.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Park, TypeOfPitch, Location, Latitude, Longitude, CityCouncil, Area, ClubName, League]
# Index: []

# %% [markdown]
# ##### Update the type of pitch

# %%
# Check for the type of pitch available in all the other dataset
print(set(fcc["TypeOfPitch"]))
print(set(dlr["TypeOfPitch"]))
# Out:
# {'All weather pitches', 'Basketball Court', 'Rugby Pitches', 'GAA Pitches', 'Tennis Courts', 'Soccer pitches', 'Seven-a-side'}
# {'3', '2', '9', 'Temporary pitch', '13', '12', 'Rugby', '8', 'Location of future pitchs', '1', 'GAA A', '6', '14', 'All weather', '11', '4', '5', 'A', 'B', 'Soccer', '10', 'GAA', 'GAA B', '7'}

# %%
## Search for GA as Gailic, FA as Football and Rugby in the Clubname and update the Pitch Type Accordingly
for i, row in dcc.iterrows():
    if any(a in dcc.iloc[i,7] for a in [" GAA"," G.A.A"]):
        dcc.iloc[i,1] = 'GAA'
    elif any(a in dcc.iloc[i,7] for a in [" A.F.C"," F.C"," FC"]):
        dcc.iloc[i,1] = 'Soccer'
    elif any(a in dcc.iloc[i,7] for a in [" RUGBY"]):
        dcc.iloc[i,1] = 'Rugby'

# %%
dcc.head()
# Out:
#              Park    TypeOfPitch              Location   Latitude  Longitude  \
# 0  ALBERT COLLEGE         Soccer        Whitehall A ED  53.383004  -6.263458
# 1  ALBERT COLLEGE  Not Available        Whitehall A ED  53.383004  -6.263458
# 2        BEECHILL         Soccer              Dublin 4  53.329195  -6.231332
# 3         BELCAMP  Not Available  Swords-Lissenhall ED  53.472847  -6.225357
# 4         BELCAMP  Not Available       Priorswood A ED  53.407424  -6.210297
#
#            CityCouncil           Area              ClubName  \
# 0  Dublin City Council     NORTH WEST  DRUMCONDRA F.C (Snr)
# 1  Dublin City Council     NORTH WEST         GLASNEVIN AFC
# 2  Dublin City Council     SOUTH EAST        BALLSBRIDGE FC
# 3  Dublin City Council  NORTH CENTRAL        NEWTOWN CELTIC
# 4  Dublin City Council  NORTH CENTRAL          VIANNEY BOYS
#
#                     League
# 0  AMATEUR FOOTBALL LEAGUE
# 1  AMATEUR FOOTBALL LEAGUE
# 2  AMATEUR FOOTBALL LEAGUE
# 3  AMATEUR FOOTBALL LEAGUE
# 4  AMATEUR FOOTBALL LEAGUE

# %% [markdown]
# ##### Check the column names in all the documents

# %%
print(list(dlr))
print(list(dcc))
print(list(fcc))
# Out:
# ['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude', 'CityCouncil']
# ['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude', 'CityCouncil', 'Area', 'ClubName', 'League']
# ['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude', 'CityCouncil']

# %% [markdown]
# #### Merge to a single dataset

# %%
# Copy all the datasets to new one to keep a backup
dcc_updated = dcc
dlr_updated = dlr
fcc_updated = fcc

# Keep only the relevant columns that match with other datasets for DLR and FCC
dcc_updated = dcc_updated[["Park","TypeOfPitch","Location","Latitude", "Longitude","CityCouncil"]]

# Check the column names for all the datasets
print(list(dlr_updated))
print(list(dcc_updated))
print(list(fcc_updated))
# Out:
# ['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude', 'CityCouncil']
# ['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude', 'CityCouncil']
# ['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude', 'CityCouncil']

# %%
#Check the datatype of each dataset before merging 
print("******* DCC ********")
print(dcc_updated.dtypes)
print("******* DLR ********")
print(dlr_updated.dtypes)
print("******* FCC ********")
print(fcc_updated.dtypes)
# Out:
# ******* DCC ********
# Park            object
# TypeOfPitch     object
# Location        object
# Latitude       float64
# Longitude      float64
# CityCouncil     object
# dtype: object
# ******* DLR ********
# Park            object
# TypeOfPitch     object
# Location        object
# Latitude       float64
# Longitude      float64
# CityCouncil     object
# dtype: object
# ******* FCC ********
# Park           object
# TypeOfPitch    object
# Location       object
# Latitude       object
# Longitude      object
# CityCouncil    object
# dtype: object

# %% [markdown]
# ##### As there are diffence in data types of different field make the data type same accross all datasets

# %%
fcc_updated['Latitude'] = fcc_updated['Latitude'].astype(np.float64)
fcc_updated['Longitude'] = fcc_updated['Longitude'].astype(np.float64)

## Recheck after modification
print("******* DCC ********")
print(dcc_updated.dtypes)
print("******* DLR ********")
print(dlr_updated.dtypes)
print("******* FCC ********")
print(fcc_updated.dtypes)
# Out:
# ******* DCC ********
# Park            object
# TypeOfPitch     object
# Location        object
# Latitude       float64
# Longitude      float64
# CityCouncil     object
# dtype: object
# ******* DLR ********
# Park            object
# TypeOfPitch     object
# Location        object
# Latitude       float64
# Longitude      float64
# CityCouncil     object
# dtype: object
# ******* FCC ********
# Park            object
# TypeOfPitch     object
# Location        object
# Latitude       float64
# Longitude      float64
# CityCouncil     object
# dtype: object

# %%
# Concat the three dataset to create a single dataset
final_data = pd.concat([fcc_updated,dlr_updated,dcc_updated])

# Reorder the columns in the final dataset
final_data = final_data[['Park', 'TypeOfPitch', 'Location', 'Latitude', 'Longitude', 'CityCouncil']]

# Check the final dataset
final_data.head(n=500)
# Out:
#                      Park          TypeOfPitch                 Location  \
# 0    Balbriggan Town Park  All weather pitches               Balbriggan
# 1      Balheary Reservoir  All weather pitches                   Swords
# 2               Town Park  All weather pitches                 Skerries
# 3       St. Mologa's Park  All weather pitches               Balbriggan
# 4          Seagrange Park     Basketball Court                Dublin 13
# 5     Grace O'Malley Park     Basketball Court                Dublin 13
# 6              Broomfiled          GAA Pitches                 Malahide
# 7    St. Catherine's Park          GAA Pitches                     Rush
# 8        Malahide Demesne          GAA Pitches                 Malahide
# 9            Swords Manor          GAA Pitches     Brackenstown, Swords
# 10          Balheary Park          GAA Pitches                   Swords
# 11          Balheary Park          GAA Pitches                   Swords
# 12          Balheary Park          GAA Pitches                   Swords
# 13         Hartstown Park          GAA Pitches                Clonsilla
# 14         Hartstown Park          GAA Pitches                Clonsilla
# 15   Hunters Run/lLittlep          GAA Pitches                   Clonee
# 16     Skerries Town Park          GAA Pitches                 Skerries
# 17            Ballist Pit          GAA Pitches                 Skerries
# 18      St. Molaga's Park          GAA Pitches               Balbriggan
# 19         Seagrange Park          GAA Pitches                Dublin 13
# 20      St. Mologa's Park        Rugby Pitches               Balbriggan
# 21         St. Catherines          GAA Pitches                Dublin 15
# 22         St. Catherines          GAA Pitches           Lucan North ED
# 23   St. Catherine's Park         Seven-a-side                     Rush
# 24                Seabury         Seven-a-side                 Malahide
# 25      Ward River Valley         Seven-a-side                   Swords
# 26          Balheary Park         Seven-a-side                   Swords
# 27          Balheary Park         Seven-a-side                   Swords
# 28          Balheary Park         Seven-a-side                   Swords
# 29     Balheary Reservoir         Seven-a-side                   Swords
# ..                    ...                  ...                      ...
# 220           BRICKFIELDS        Not Available                Dublin 12
# 221           BRICKFIELDS               Soccer                Dublin 12
# 222           BRICKFIELDS        Not Available                Dublin 12
# 223           BRICKFIELDS               Soccer                Dublin 12
# 224                 BUSHY        Not Available            Terenure D ED
# 225                 BUSHY        Not Available            Terenure D ED
# 226               FARNHAM               Soccer                Dublin 11
# 227           FR. COLLINS        Not Available   Shankill-Shanganagh ED
# 228               HERBERT               Soccer       Pembroke West B ED
# 229             JOHNSTOWN               Soccer           Ballygall B ED
# 230              ST ANNES               Soccer   Shankill-Shanganagh ED
# 231              ST ANNES               Soccer   Shankill-Shanganagh ED
# 232              ST ANNES        Not Available   Shankill-Shanganagh ED
# 233              ST ANNES        Not Available   Shankill-Shanganagh ED
# 234           BRICKFIELDS               Soccer                Dublin 12
# 235           BRICKFIELDS        Not Available                Dublin 12
# 236           BRICKFIELDS        Not Available                Dublin 12
# 237            DONAGHMEDE        Not Available              Grange B ED
# 238               FARNHAM        Not Available                Dublin 11
# 239           FR. COLLINS        Not Available  Shankill-Rathsallagh ED
# 240               LE FANU               Soccer                Dublin 20
# 241              ST ANNES        Not Available   Shankill-Shanganagh ED
# 242              ST ANNES        Not Available   Shankill-Shanganagh ED
# 243              ST ANNES        Not Available   Shankill-Shanganagh ED
# 244              ST ANNES        Not Available   Shankill-Shanganagh ED
# 245             STANNAWAY               Soccer             Kimmage B ED
# 246           WALKINSTOWN        Not Available         Walkinstown A ED
# 247              ST ANNES        Not Available   Shankill-Shanganagh ED
# 248               BELCAMP               Soccer          Priorswood A ED
# 249              ST ANNES               Soccer   Shankill-Shanganagh ED
#
#       Latitude  Longitude          CityCouncil
# 0    53.604960  -6.182353               Fingal
# 1    53.472710  -6.223015               Fingal
# 2    53.577114  -6.111072               Fingal
# 3    53.617667  -6.189368               Fingal
# 4    53.396667  -6.135352               Fingal
# 5    53.383767  -6.069940               Fingal
# 6    53.439158  -6.144672               Fingal
# 7    53.538198  -6.095941               Fingal
# 8    53.447818  -6.157841               Fingal
# 9    53.459173  -6.249069               Fingal
# 10   53.467127  -6.220345               Fingal
# 11   53.466035  -6.216120               Fingal
# 12   53.467349  -6.215388               Fingal
# 13   53.395924  -6.411545               Fingal
# 14   53.395323  -6.412928               Fingal
# 15   53.406392  -6.421911               Fingal
# 16   53.576529  -6.109167               Fingal
# 17   53.575297  -6.117402               Fingal
# 18   53.618139  -6.187964               Fingal
# 19   53.393783  -6.136071               Fingal
# 20   53.619292  -6.189092               Fingal
# 21   53.366202  -6.467748               Fingal
# 22   53.366173  -6.466007               Fingal
# 23   53.539338  -6.094502               Fingal
# 24   53.455547  -6.177812               Fingal
# 25   53.455814  -6.249574               Fingal
# 26   53.465761  -6.218399               Fingal
# 27   53.466271  -6.218101               Fingal
# 28   53.466798  -6.218095               Fingal
# 29   53.472354  -6.226153               Fingal
# ..         ...        ...                  ...
# 220  53.332679  -6.305907  Dublin City Council
# 221  53.332679  -6.305907  Dublin City Council
# 222  53.332679  -6.305907  Dublin City Council
# 223  53.332679  -6.305907  Dublin City Council
# 224  53.302120  -6.291446  Dublin City Council
# 225  53.302120  -6.291446  Dublin City Council
# 226  53.385891  -6.300376  Dublin City Council
# 227  53.228847  -6.117390  Dublin City Council
# 228  53.327687  -6.236570  Dublin City Council
# 229  53.385607  -6.282666  Dublin City Council
# 230  53.228847  -6.117390  Dublin City Council
# 231  53.228847  -6.117390  Dublin City Council
# 232  53.228847  -6.117390  Dublin City Council
# 233  53.228847  -6.117390  Dublin City Council
# 234  53.332679  -6.305907  Dublin City Council
# 235  53.332679  -6.305907  Dublin City Council
# 236  53.332679  -6.305907  Dublin City Council
# 237  53.396732  -6.154492  Dublin City Council
# 238  53.385891  -6.300376  Dublin City Council
# 239  53.240430  -6.126469  Dublin City Council
# 240  53.347915  -6.345197  Dublin City Council
# 241  53.228847  -6.117390  Dublin City Council
# 242  53.228847  -6.117390  Dublin City Council
# 243  53.228847  -6.117390  Dublin City Council
# 244  53.228847  -6.117390  Dublin City Council
# 245  53.320687  -6.300689  Dublin City Council
# 246  53.320207  -6.342239  Dublin City Council
# 247  53.228847  -6.117390  Dublin City Council
# 248  53.407424  -6.210297  Dublin City Council
# 249  53.228847  -6.117390  Dublin City Council
#
# [407 rows x 6 columns]

# %%
### Write To a csv file 
final_data.to_csv("Combined_pitch_details.csv", encoding='utf-8', index=False)

# %% [markdown]
# #### Visualise the Latitude Longitude in Map View to see the data

# %%
##  Create separate dataset for Latitude Longitude Data
dcc_locations = dcc_updated[['Latitude', 'Longitude']]
fcc_locations = fcc_updated[['Latitude', 'Longitude']]
dlr_locations = dlr_updated[['Latitude', 'Longitude']]

# %%
# Convert to a list of tuples
dcc_locationlist = dcc_locations.values.tolist()
fcc_locationlist = fcc_locations.values.tolist()
dlr_locationlist = dlr_locations.values.tolist()

# %%
# Take those values apart from the NAN Values
dcc_locationlist= [n for n in dcc_locationlist if not np.nan in n]
fcc_locationlist= [n for n in fcc_locationlist if not np.nan in n]
dlr_locationlist= [n for n in dlr_locationlist if not np.nan in n]

# %%
# Plot the data in the Map 
# Green - For FCC
# Blue - For DCC
# Red - For DLR
map = folium.Map(location=[53.3498, -6.2603], zoom_start=12)
for point in range(0, len(fcc_locationlist)):
    folium.Marker(fcc_locationlist[point],
                  icon=folium.Icon(color='green')).add_to(map)

for point in range(0, len(dcc_locationlist)):
    folium.Marker(dcc_locationlist[point],
                  icon=folium.Icon(color='blue')).add_to(map)

for point in range(0, len(dlr_locationlist)):
    folium.Marker(dlr_locationlist[point],
                  icon=folium.Icon(color='red')).add_to(map)

# %%
# Draw the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
